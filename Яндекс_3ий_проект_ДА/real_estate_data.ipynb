# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Обзор-данных." data-toc-modified-id="Обзор-данных.-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Обзор данных.</a></span><ul class="toc-item"><li><span><a href="#Основная-задача." data-toc-modified-id="Основная-задача.-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Основная задача.</a></span></li><li><span><a href="#Цель." data-toc-modified-id="Цель.-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Цель.</a></span></li><li><span><a href="#Название-столбцов." data-toc-modified-id="Название-столбцов.-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Название столбцов.</a></span></li><li><span><a href="#Краткий-план." data-toc-modified-id="Краткий-план.-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Краткий план.</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Вывод." data-toc-modified-id="Вывод.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Вывод.</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Зависимости" data-toc-modified-id="Зависимости-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Зависимости</a></span></li><li><span><a href="#10-населённых-пунктов-с-наибольшим-числом-объявлений." data-toc-modified-id="10-населённых-пунктов-с-наибольшим-числом-объявлений.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>10 населённых пунктов с наибольшим числом объявлений.</a></span></li><li><span><a href="#Центр" data-toc-modified-id="Центр-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Центр</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В нашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Наша задача - научиться определять рыночную стоимость объектов недвижимости. Установим параметры, что позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ## Обзор данных.
# ### Основная задача.
# - Научиться определять рыночную стоимость объектов недвижимости.
#
# ### Цель.
#
# - Построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# ### Название столбцов.
#
# - airports_nearest — расстояние до ближайшего аэропорта в метрах (м);
# - balcony — число балконов;
# - ceiling_height — высота потолков (м);
# - cityCenters_nearest — расстояние до центра города (м);
# - days_exposition — сколько дней было размещено объявление (от публикации до снятия);
# - first_day_exposition — дата публикации;
# - floor — этаж;
# - floors_total — всего этажей в доме;
# - is_apartment — апартаменты (булев тип);
# - kitchen_area — площадь кухни в квадратных метрах (м²);
# - last_price — цена на момент снятия с публикации;
# - living_area — жилая площадь в квадратных метрах (м²);
# - locality_name — название населённого пункта;
# - open_plan — свободная планировка (булев тип);
# - parks_around3000 — число парков в радиусе 3 км;
# - parks_nearest — расстояние до ближайшего парка (м);
# - ponds_around3000 — число водоёмов в радиусе 3 км;
# - ponds_nearest — расстояние до ближайшего водоёма (м);
# - rooms — число комнат;
# - studio — квартира-студия (булев тип);
# - total_area — площадь квартиры в квадратных метрах (м²);
# - total_images — число фотографий квартиры в объявлении.

# %% [markdown]
# ### Краткий план.
#
# 1. Изучим полученные данные и зафиксируем, что необходимо исправить;
# 2. Проведем предобработку данных;
# 3. Добавим необходимые данные в таблицу;
# 4. Изучим и визуализируем полученную информацию;
# 5. Составим топ городов по цене и выделим центральную зону;
# 7. Сравним центральную выборку с общей;
# 8. Напишем общий вывод.

# %%
# импортируем необходимые библиотеки
import pandas as pd
import os

# %%
# считываем данные
path = 'C:\\Users\\tbyni\\Рабочий стол\\YA_DA12+\\3 Исследовательский анализ данных\\проект\\Яндекс_3ий_проект_ДА\\'
df = pd.read_csv(path + 'real_estate_data.csv', sep = '\t')

# %%
# check
pth1 = 'real_estate_data.csv'
pth2 = '/datasets/real_estate_data.csv'

if os.path.exists(pth1):
    df = pd.read_csv(pth1)
elif os.path.exists(pth2):
    df = pd.read_csv(pth2)
else:
    print('Something is wrong')
# Out:
# Something is wrong

# %%
# просматриваем общую информацию о данных
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
# получим первые 20 строк 
df.head(20)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1              7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2             10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3              0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4              2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6              6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7              5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9             18   5400000.0       61.00  2017-02-26T00:00:00      3
# 10             5   5050000.0       39.60  2017-11-16T00:00:00      1
# 11             9   3300000.0       44.00  2018-08-27T00:00:00      2
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# ...

# %%
# просмотрим общую информацию о датафрейме
df.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    14504.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        1.261056
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  12180.000000
# mean      10.673824     34.457852      5.892358     10.569807      1.150082
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Следующие столбцы требуют обработки: first_day_exposition, ceiling_height, floors_total, living_area, is_apartment, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition. Общее кол-во строк: 23699.
#
# В процессе обработки опишем проделанную работу.

# %% [markdown]
# ## Предобработка данных

# %%
# просмотрим кол-во пропущенных значений
df.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %%
# check
# пропущенные значения бары

def pass_value_barh(df):
    (
        (df.isna().mean()*100)
        .to_frame()
        .rename(columns = {0:'space'})
        .query('space > 0')
        .sort_values(by = 'space', ascending = True)
        .plot(kind= 'barh', figsize=(19,6), rot = 0, legend = False, fontsize = 16)
        .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')    
    );

# %%
# check
pass_value_barh(df)

# %%
# просмотрим кол-во пропусков в столбце 
df['balcony'].value_counts() 
df['balcony'] = df['balcony'].fillna(0)

# %%
# изменим тип данных на целочисленный 
df['balcony'] = df['balcony'].astype('int')

# %%
# просмотрим квартиры высота потолков которых выше 6м
df.query('ceiling_height > 6')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 355              17   3600000.0        55.2  2018-07-12T00:00:00      2
# 3148             14   2900000.0        75.0  2018-11-12T00:00:00      3
# 3474              3   1400000.0        30.0  2018-03-16T00:00:00      1
# 4643              0   4300000.0        45.0  2018-02-01T00:00:00      2
# 4876              7   3000000.0        25.0  2017-09-27T00:00:00      0
# 5076              0   3850000.0        30.5  2018-10-03T00:00:00      1
# 5246              0   2500000.0        54.0  2017-10-13T00:00:00      2
# 5669              4   4400000.0        50.0  2017-08-08T00:00:00      2
# 5807             17   8150000.0        80.0  2019-01-09T00:00:00      2
# 5863             20   5650000.0        45.0  2018-08-15T00:00:00      1
# 6246              6   3300000.0        44.4  2019-03-25T00:00:00      2
# 9379              5   3950000.0        42.0  2017-03-26T00:00:00      3
# ...

# %%
# просмотрим медианные значения по высоте потолков
df.ceiling_height.median()
# Out:
# 2.65

# %%
# заменим пропущенные значения медианой 
df['ceiling_height'] = df['ceiling_height'].fillna(df['ceiling_height'].median())
df.ceiling_height.isnull().sum() # check
# Out:
# 0

# %%
# приведем формат данных к корректному datetime 
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format = '%Y-%m-%d')

# %%
# изменим формат данных на целочисленный
df['last_price'] = df['last_price'].astype(int)

# %%
# удалим пропуски в столбце locality name (<5%)
df.dropna(subset=['locality_name'], how='all', inplace=True)
df['locality_name'].isnull().sum() # check
# Out:
# 0

# %%
# удалим пропуски в столбце floors_total (<5%)
df.dropna(subset=['floors_total'], how='all', inplace=True)
df['floors_total'].isnull().sum() # check
# Out:
# 0

# %%
# меняем формат данных на целочисленный 
df['floors_total'] = df['floors_total'].astype('int')

# %%
# изменяем тип данных на bool. 
df['is_apartment'] = df['is_apartment'].astype('bool')

# %%
# смотрим соотношение насленного пункта и удаленности от центра. 
df_cityCenters = df.pivot_table(index = 'locality_name',values = 'cityCenters_nearest')
df_cityCenters['cityCenters_nearest'].plot(kind='hist', bins=100, grid=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### Вывод.
#
# - В столбце с балконами пропущенные значения, предположим, что балкона просто нет и пользователь не указал, заполним нулями.(balcony).
# - Согласно существующему документу - СНиП 31-01-2003. Высоту полотков, в особых клматических зонах - IА, IБ, IГ, IД и IVA должна быть не менее 2.7 м, Петербург в эти зоны не входит, поэтому пропущенные значения заполним медианой (2.65 м.);
# - Изменили формат для столбца first_day_exposition на корректный;
# - locality_name общий процент пропуска очень низкий, поэтому просто удалим их;
# - last_price преобразовали в целочисленный формат;
# - floors_total удалили пропущенные значения;
# - Исходя из полученных данных по столбцу cityCenters_nearest можем заметить, что основнпя масса объектов на ходится в пределах 8 км
# - is_apartment преобразовали на необходимый формат

# %%
# просматриваем обработанные данные
display(df.info())
display(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  int32
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  datetime64[ns]
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23565 non-null  float64
#  6   floors_total          23565 non-null  int32
#  7   living_area           21700 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          21343 non-null  float64
#  13  balcony               23565 non-null  int32
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %%
# cчитаем цену за квадратный метр
df['cost_for_metre'] =(df['last_price'] / df['total_area'] * 100).round()/100

# %%
# cоздаем столбец с днями недели
df['week_exposition'] = df['first_day_exposition'].dt.weekday

# %%
# создаем столбец с месяцами
df['month_exposition'] = df['first_day_exposition'].dt.month

# %%
# создаем столбец с годом
df['year_exposition'] = df['first_day_exposition'].dt.year

# %%
# поэтажная категоризация
def categ_floor(row):
    if row['floor'] == 1:
        return 'первый'
    elif row['floor'] == row['floors_total']:
        return 'последний'
    return 'другой'
df['categ_floor'] = df.apply(categ_floor, axis = 1)

# %%
# подсчитываем соотношение жилой и общей площади. 
df['living_area_ratio'] = (df['living_area'] / df['total_area']* 100).round()/100

# %%
# подсчитываем соотношение площади кухни к общей.
df['kitchen_area_ratio'] = (df['kitchen_area'] / df['total_area']* 100).round()/100

# %%
# просмотрим на анономалии в записях т.к есть (коридоры, сан.узлы, балконы) 
df_ratio_check = df['living_area_ratio'] + df['kitchen_area_ratio'] >= 0.95
df_ratio_check.value_counts()
# Out:
# False    23317
# True       248
# dtype: int64

# %%
# проверяем ранее добавленные столбцы. 
df.head(20)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20    13000000      108.00           2019-03-07      3
# 1              7     3350000       40.40           2018-12-04      1
# 2             10     5196000       56.00           2015-08-20      2
# 3              0    64900000      159.00           2015-07-24      3
# 4              2    10000000      100.00           2018-06-19      2
# 5             10     2890000       30.40           2018-09-10      1
# 6              6     3700000       37.30           2017-11-02      1
# 7              5     7915000       71.60           2019-04-18      2
# 8             20     2900000       33.16           2018-05-23      1
# 9             18     5400000       61.00           2017-02-26      3
# 10             5     5050000       39.60           2017-11-16      1
# 11             9     3300000       44.00           2018-08-27      2
# 12            10     3890000       54.00           2016-06-30      2
# ...

# %% [markdown]
# ### Вывод
#
# - Получена стоимость квадратного метра;
# - Добавлены столбцы с днями, месяцами и года по дате публикации;
# - Категоризовал квартиры поэтажно;
# - Посчитаны и добавлены новые столбцы с данными по соотношению жилой и общей площади, а также отношение площади кухни к общей.

# %% [markdown]
# ## Исследовательский анализ данных

# %%
# визуализируем соотношение площади и кол-ва квартир. 
total_area_visual = df['total_area'].plot(kind='hist', bins=100, range=(0,250), title='Общая площадь', grid=True)
total_area_visual.set_xlabel('Площадь квартиры')
total_area_visual.set_ylabel('Кол-во квартир')
df['total_area'].describe()
# Out:
# count    23565.000000
# mean        60.322824
# std         35.657060
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.700000
# max        900.000000
# Name: total_area, dtype: float64

# %%
# визуализируем соотношение жилой площади и кол-ва квартир 
total_area_visual = df['living_area'].plot(kind='hist', bins=200, range=(0,180), title='Жилая площадь кв', grid=True)
total_area_visual.set_xlabel('Жилая площадь квартиры')
total_area_visual.set_ylabel('Кол-во квартир')
df['living_area'].describe()
# Out:
# count    21700.000000
# mean        34.454822
# std         22.045359
# min          2.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.300000
# max        409.700000
# Name: living_area, dtype: float64

# %% [markdown]
# Наибольшую плотность наблюдаем в промежутке 40м2 - 60м2. Причем можем увидеть большой всплеск в районе 40м2 - 45м2, возможно это связано тем, что наиболее популярные квартиры находятся в этом диапазоне.

# %%
# визуализируем соотношение последнего прайса и кол-ва квартир. 
last_price_visual = df['last_price'].plot(kind='hist', bins=200, range=(1000000,10000000), title='Распределение кол-ва квартир по цене', grid=True)
last_price_visual.set_xlabel('Суммы продажи')
last_price_visual.set_ylabel('Кол-во квартир')
df['last_price'].describe()
# Out:
# count    2.356500e+04
# mean     6.540058e+06
# std      1.091093e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.646000e+06
# 75%      6.790000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %% [markdown]
# Наблюдаем, что наибольший всплеск продаж наблюдается в районе 3-5 млн., дальше идет постепенный спад с отдельными взлетами.

# %%
# визуализируем соотношение кол-ва комнат и кол-ва квартир 
rooms_visual = df['rooms'].plot(kind='hist', bins=80, range=(0,16), title='Категоризация квартир по кол-ву комнат', grid=True)
rooms_visual.set_xlabel('Кол-во комнат в кв.')
rooms_visual.set_ylabel('Кол-во квартир')
df['rooms'].describe()
# Out:
# count    23565.000000
# mean         2.070656
# std          1.078591
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %% [markdown]
# Как мы могли ранее заметить наибольшее кол-во квартир 1 и 2х комнатных.

# %%
# визуализируем соотношение высоты потолков и кол-ва квартир. 
ceiling_height_visual = df['ceiling_height'].plot(kind='hist', bins=100, range=(2.5,6), title='Категоризация кв. по высоте потолков', grid=True)
ceiling_height_visual.set_xlabel('Высота потолка')
ceiling_height_visual.set_ylabel('Кол-во квартир')
df['ceiling_height'].describe()
# Out:
# count    23565.000000
# mean         2.724530
# std          0.991026
# min          1.000000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Значительное кол-во квартир с высотой потолков в промежутке 2,5м. - 2,8м. Все согласно СНиП 31-01-2003. С небольшим уклоном к 2.7 м.

# %% [markdown]
# Кратко можно сказать, что очень востребованы 1-2х комнатные квартиры, площадью 40м2 - 60м2, высотой потолков от 2,5 до 2,8м. и ценой в районе 3-5 млн.

# %%
# подсчитываем среднее значение по времени размещения обьявления.
df['days_exposition'].mean()
# Out:
# 180.7413945278023

# %%
# подсчитываем медианное значение по времени размещения обьявления.
df['days_exposition'].median()
# Out:
# 95.0

# %%
# сортируем кол-во квартир по кол-ву дней продажи. 
days_exposition_visual = df['days_exposition'].plot(kind='hist', bins=70, range=(5,1000), title='Категоризация от момента размещения обьявления до продажи квартиры', grid=True)
days_exposition_visual.set_xlabel('Дни размещения')
days_exposition_visual.set_ylabel('Кол-во квартир')
df['days_exposition'].describe()
# Out:
# count    20394.000000
# mean       180.741395
# std        219.732782
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
# детализируем 
days_exposition_visual = df['days_exposition'].plot(kind='hist', bins=30, range=(0,150), title='Категоризация от момента размещения обьявления до продажи квартиры', grid=True)
days_exposition_visual.set_xlabel('Дни размещения')
days_exposition_visual.set_ylabel('Кол-во квартир')
df['days_exposition'].describe()
# Out:
# count    20394.000000
# mean       180.741395
# std        219.732782
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
# детализируем
days_exposition_visual = df['days_exposition'].plot(kind='hist', bins=55, range=(40,100), title='Категоризация от момента размещения обьявления до продажи квартиры', grid=True)
days_exposition_visual.set_xlabel('Дни размещения')
days_exposition_visual.set_ylabel('Кол-во квартир')
df['days_exposition'].describe()
# Out:
# count    20394.000000
# mean       180.741395
# std        219.732782
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Отметим странные всплески в 45, 60 и 90 дни, просмотрев правила размещения объявлений Яндекс недвижимости можем предположить это связано с тем, что в эти дни заканчивается срок размещения и необходимо обновлять объявление.

# %%
# изучаем ранее заявленную информацию с сайта "Домофонда"
df_check = df.pivot_table(index = 'rooms', values = 'days_exposition', aggfunc = ['mean', 'count', 'median'])
df_check
df_check.columns = ['mean', 'count', 'median']
df_check.query('count > 50').plot(y = 'median')

df_check.query('count > 50').sort_values('median', ascending = False)
# Out:
#              mean  count  median
# rooms
# 6      277.789474     76   201.5
# 5      307.139442    251   191.0
# 4      253.734191    933   155.0
# 3      204.193023   4787   114.0
# 2      172.990540   6871    91.0
# 1      158.764478   7235    81.0
# 0      110.322222    180    49.5

# %% [markdown]
# Видим, как с увеличением кол-ва комнат, увеличивается и срок продажи квартиры.

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных показателях 
# в выбранных параметрах о продаже квартир
# сырые данные

(
   df[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area', 'floor',
       'floors_total']]
    .apply (['count', 'min', 'max'])   
    .style.format("{:,.2f}")
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6ebf7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >rooms</th>
#       <th class="col_heading level0 col1" >total_area</th>
#       <th class="col_heading level0 col2" >ceiling_height</th>
#       <th class="col_heading level0 col3" >days_exposition</th>
#       <th class="col_heading level0 col4" >last_price</th>
#       <th class="col_heading level0 col5" >living_area</th>
#       <th class="col_heading level0 col6" >kitchen_area</th>
#       <th class="col_heading level0 col7" >floor</th>
#       <th class="col_heading level0 col8" >floors_total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ebf7_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_6ebf7_row0_col0" class="data row0 col0" >23,565.00</td>
#       <td id="T_6ebf7_row0_col1" class="data row0 col1" >23,565.00</td>
# ...

# %%
# удаляем выбивающиеся значения для комнат. 
df = df.drop(df[df['rooms'] >= 8].index)
df['rooms'].value_counts().sum()
# Out:
# 23534

# %%
# убираем выбивающиеся значения для общей площади
# df.value_counts([df['total_area'] >= 250]) # check
df = df.drop(df[df['total_area'] >= 250].index)

# %%
# df.value_counts([df['total_area'] <= 18]) # check
df = df.drop(df[df['total_area'] <= 18].index)
df['total_area'].value_counts().sum()
# Out:
# 23416

# %%
# удаляем выбивающиеся значения, т.к минмальная высота по закону 2,50, а высота потолков 5,2м. берем эти значения.
 # df.value_counts([df['ceiling_height'] <= 2.49]) # check
df = df.drop(df[df['ceiling_height'] <= 2.49].index)

# %%
# удаляем выбивающиеся значения, т.к минмальная высота по закону 2,50, а высота потолков 5,2м. берем эти значения.
# df.value_counts([df['ceiling_height'] >= 5.20])
df = df.drop(df[df['ceiling_height'] >= 5.20].index)
# df['ceiling_height'].value_counts().sum() # check

# %%
# ограничим срок продажи до 2 лет.
df = df.drop(df[df['days_exposition'] >= 730].index)
# df.value_counts([df['days_exposition'] >= 730]) # check

# %%
# ограничим сумму 1 млн.
df = df.drop(df[df['last_price'] <= 1000000].index)
# df.value_counts([df['last_price'] <= 1000000]) # check

# %%
# минимальная возможная жидая площадь на человека в Петербурге 9м2.
df = df.drop(df[df['living_area'] <= 8.99].index)    
# df.value_counts([df['living_area'] <= 8.99])

# %%
# кухня имеет ограничение не менее 5м2. 
df = df.drop(df[df['kitchen_area'] <= 4.99].index)    
# df.value_counts([df['kitchen_area'] <= 8.99])

# %%
# ограничим этажность 32 этажами.  
# df['floors_total'].value_counts()
df = df.drop(df[df['floors_total'] >= 32].index)

# %%
# check
display(df.describe())
display(df.info())
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  22196.000000  2.219600e+04  22196.000000  22196.000000    22196.000000
# mean       9.932060  6.194397e+06     58.845697      2.046540        2.694225
# std        5.682021  6.943170e+06     28.283840      1.011868        0.208899
# min        0.000000  1.010000e+06     18.500000      0.000000        2.500000
# 25%        6.000000  3.480000e+06     40.000000      1.000000        2.600000
# 50%       10.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.700000e+06     69.000000      3.000000        2.700000
# max       50.000000  3.300000e+08    249.700000      7.000000        4.900000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  22196.000000  20456.000000  22196.000000  20128.000000  22196.000000
# mean      10.771445     33.633574      5.919490     10.461172      0.600063
# ...

# %% [markdown]
# - В столбце rooms ограничим кол-во комнат до 8. Процент потерь менее 5%;
# - Согласно данным, кв. в СПб имеют метраж в рамках 18м2(студии) до 250м2 для больших апартаментов;
# - Высоту потолков (столбец - ceiling_height) установим в рамках от 2,50м(по закону) до 5,20м.(в некоторых аппартаментах);
# - Продажу квартир по столбцу days_exposition ограничим 2 годами;
# - Согласно открытым источникам минимальная сумма за кв. метр по лен. обл. в 2016 г. = 52 561 руб., а так как минимальная студия у нас 18м2, то сумма менее 1млн, быть не может. Удалим выбивающиеся значения;
# - Минимальную жилую площадь ограничим 9м2, в Петербурге это минимальный метраж по закону;
# - Минимальный размер кухни 5м2;
# - Согласно информации из открытых источников средняя этажность по СПб 20 этажей и зачастую не более 32 этажей, остальное отбросим.

# %% [markdown]
# ### Зависимости

# %%
# просматриваем зависимость между общей площадью и последней ценой
compare2_area = df.pivot_table(index = 'total_area', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
compare2_area.columns = ['mean', 'count', 'median']
compare2_area.plot(y = 'median', style = 'x')

compare2_area.sort_values('median', ascending = False)

df['total_area'].corr(df['last_price'])
# Out:
# 0.6672200564364811

# %% [markdown]
# Можем заметить, как с увеличением площади растет и цена за квартиру.

# %%
# просматриваем зависимость между кол-вом комнат и последней ценой 
compare_rooms = df.pivot_table(index = 'rooms', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
compare_rooms.columns = ['mean', 'count', 'median']
compare_rooms.query('count > 50').plot(y = 'median')

compare_rooms.query('count > 50').sort_values('median', ascending = False)

df['rooms'].corr(df['last_price'])
# Out:
# 0.38815616150204185

# %% [markdown]
# На графике заметно, что резкий рост происходит начиная с 3х комнатной квартиры, в данном случае можем предположить, что цена между 2х и 3х комнатными квартирами не столь велика.

# %%
# просматриваем разницу между этажами
compare_categ2_floor = df.pivot_table(index = 'categ_floor', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
compare_categ2_floor.columns = ['mean', 'count', 'median']
compare_categ2_floor.plot(y = 'median')
compare_categ2_floor
# Out:
#                      mean  count   median
# categ_floor
# другой       6.434789e+06  16477  4800000
# первый       4.805895e+06   2672  3975000
# последний    6.112069e+06   3047  4350000

# %% [markdown]
# Разница в стоимости между первым и последним 12% люди охотнее берут квартиры на последнем этаже.
# Тогда как разница между последним и другими этажами 10%. Значит предпологаем, что люди берут активнее квартиры на других этажах.

# %%
# просматриваем зависимость удаленности кв. от центра и ценой за кв. метр 
df.plot(kind = 'scatter', y = 'last_price', x = 'cityCenters_nearest', alpha = 0.3)
df['cityCenters_nearest'].corr(df['last_price'])
# Out:
# -0.26809289430111094

# %% [markdown]
# На диаграмме прослеживается зависимость стоимости от удаленности от центра.

# %%
# изучаем зависимость цены от дня выставления обьявления 
compare_week_exposition = df.pivot_table(index = 'week_exposition', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
compare_week_exposition.columns = ['mean', 'count', 'median']
compare_week_exposition.plot(y = 'median')

compare_week_exposition.sort_values('median', ascending = False)
# Out:
#                          mean  count   median
# week_exposition
# 1                6.175609e+06   3922  4700000
# 2                6.241354e+06   3688  4700000
# 0                6.191144e+06   3395  4650000
# 3                6.442660e+06   4017  4630000
# 5                6.071618e+06   1807  4600000
# 4                6.033869e+06   3786  4599500
# 6                6.032416e+06   1581  4550000

# %% [markdown]
# Можем заметить, как падает активность к субботе, предположим, что это связано с тем, что к выходным снижается деловая активность.

# %%
# изучаем зависимость цены от месяца выставления обьявления 
compare_month_exposition = df.pivot_table(index = 'month_exposition', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
compare_month_exposition.columns = ['mean', 'count', 'median']
compare_month_exposition.plot(y = 'median')

compare_month_exposition.sort_values('median', ascending = False)
# Out:
#                           mean  count   median
# month_exposition
# 4                 6.325668e+06   2239  4800000
# 11                6.225454e+06   2246  4700000
# 9                 6.228927e+06   1850  4690000
# 3                 6.094049e+06   2389  4685000
# 12                6.268935e+06   1502  4685000
# 2                 6.272383e+06   2491  4680000
# 7                 6.193267e+06   1580  4650000
# 1                 6.266016e+06   1400  4600000
# 8                 6.351523e+06   1662  4600000
# 10                5.916522e+06   2012  4560000
# 5                 6.143894e+06   1185  4530000
# 6                 6.051273e+06   1640  4425000

# %% [markdown]
# Наибольшую активность можем отметить под конец года и весной, под конец года ожидаемо люди пытаются закрыть сделки в предстоящем году и готовы снижать цены, а весной идет время перед летним затишьем.

# %%
# изучаем зависимость цены от года выставления обьявления 
compare_year_exposition = df.pivot_table(index = 'year_exposition', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
compare_year_exposition.columns = ['mean', 'count', 'median']
compare_year_exposition.plot(y = 'median')

compare_year_exposition.sort_values('median', ascending = False)
# Out:
#                          mean  count   median
# year_exposition
# 2014             1.191270e+07     61  8585256
# 2015             8.279473e+06    750  5100000
# 2019             6.627080e+06   2786  5100000
# 2018             5.863628e+06   8232  4600000
# 2016             6.248382e+06   2418  4500000
# 2017             6.128261e+06   7949  4500000

# %% [markdown]
# 1. Зависимость от дней.
# - В будни заключаются основные сделки, агенты выставляют квартиры на продажу, обновляют "старые" объявления к выходным деловая активность снижается
#
# 2. Зависимость от месяца.
# - Первые 2 месяца ожидаемый спад в продажах люди не спеша выходят из праздников и во всех сферах, как правило наблюдается спад. Далее идет пик деловой активности вплоть до майских праздников пока не начнется сезон отпусков, согласно риэлторским сайтам лето это "мертвый" сезон на рынке вторичного жилья, далее идет всплеск, т.к люди отдохнувшие после лета и готовы к покупкам, следующий пик наблюдается в декабре, т.к многие хотят завершить сделку в этом году. (Отдельно хочу заметить, что в южных регионах будут другие показатели, сезонность)
#
# 3. Зависимость от года.
# - С развитием сервиса увеличивалось и кол-во объявлений с 61 в 2014 году до 8232 в 2018 году, с увеличением кол-ва объявлений выровнялась и медиана в рамках 4-5 млн.

# %% [markdown]
# ### 10 населённых пунктов с наибольшим числом объявлений.

# %%
# 10 населённых пунктов с наибольшим числом объявлений
locality = df['locality_name'].value_counts().head(10)
locality_price = df.pivot_table(index='locality_name', values='cost_for_metre')
top_locality = locality_price.merge(locality,  how='right', left_index=True, right_index=True)
top_locality.sort_values(by='cost_for_metre', ascending=False)
# Out:
#                    cost_for_metre  locality_name
# Санкт-Петербург     113729.115831          14865
# Пушкин              103188.101936            346
# деревня Кудрово      92614.779107            280
# посёлок Парголово    90049.485455            319
# посёлок Мурино       85625.021891            497
# посёлок Шушары       78486.521200            425
# Колпино              75282.176545            330
# Гатчина              69177.479825            286
# Всеволожск           68907.843724            384
# Выборг               58971.854369            222

# %% [markdown]
# Тут логично предположить, что в Петербурге самые дорогие квартиры. Из неожиданного могу заметить, что например квартиры в Шушарах дешевле, чем в Пушкине, потому что Шушары около КАДа, а до Пушкина еще доехать надо. В "аутсайдерах" ожидаемо Выборг потому что он наиболее удален от Петербурга.

# %%
# получаем расстояние в км. 
df.query('locality_name == "Санкт-Петербург"')
df['km_to_cntr'] = df['cityCenters_nearest'] / 1000
df['km_to_cntr'] = df['km_to_cntr'].round()

# %%
# цена за метр и удаленность от центра в км. 
cost_for_metre_cntr = df.groupby(['km_to_cntr'])['cost_for_metre'].median()
cost_for_metre_cntr = cost_for_metre_cntr.to_frame()
cost_for_metre_cntr['km_to_cntr'] = cost_for_metre_cntr.index
cost_for_metre_cntr.head(30)
# Out:
#             cost_for_metre  km_to_cntr
# km_to_cntr
# 0.0             150243.965         0.0
# 1.0             127731.090         1.0
# 2.0             121136.170         2.0
# 3.0             109122.155         3.0
# 4.0             118055.560         4.0
# 5.0             126166.180         5.0
# 6.0             129443.085         6.0
# 7.0             126063.830         7.0
# 8.0             122235.805         8.0
# 9.0             106250.000         9.0
# 10.0            106442.365        10.0
# 11.0            103201.970        11.0
# 12.0            104138.130        12.0
# 13.0            104166.670        13.0
# 14.0            101983.000        14.0
# 15.0            101363.640        15.0
# 16.0             97500.000        16.0
# 17.0             94857.140        17.0
# 18.0             92008.870        18.0
# 19.0             97035.040        19.0
# 20.0             87268.545        20.0
# 21.0             83841.460        21.0
# 22.0             87551.960        22.0
# ...

# %%
# визуализируем ранее полученные данные 
cost_for_metre_cntr.plot('km_to_cntr')
# Out:
# <AxesSubplot:xlabel='km_to_cntr'>

# %%
# просмотрим детально возможные выбросы 
cost_for_metre_cntr.plot('km_to_cntr', style = 'o', figsize = (14,4));

# %% [markdown]
# Из полученных данных прослеживается, что центр находится в районе 3 км, далее есть скачки цен, но в данном случае это уже зависит от района, например Петроградский район дороже чем Адмиралтейский, причем значительно хотя оба находятся в центре.

# %%
 # Выделяем центральную зону.
spb_city_center =  df[df['km_to_cntr'] <= 8]
spb_city_center.head(20)
# Out:
#      total_images  last_price  total_area first_day_exposition  rooms  \
# 3               0    64900000       159.0           2015-07-24      3
# 4               2    10000000       100.0           2018-06-19      2
# 24              8     6500000        97.2           2015-10-31      2
# 35              6    15500000       149.0           2017-06-26      5
# 51              7    45000000       161.0           2017-10-17      3
# 52             20    11795000       136.0           2017-09-22      6
# 61             18     7990000        74.0           2017-08-24      2
# 63              2    20000000       118.0           2018-09-11      3
# 70              9     3400000        30.0           2018-09-05      1
# 94              3     3500000        29.5           2019-04-26      1
# 99             32     9600000        90.0           2017-09-26      4
# 106             9    10500000       124.1           2017-05-25      5
# ...

# %%
# check
spb_city_center.locality_name.unique()
# Out:
# array(['Санкт-Петербург'], dtype=object)

# %% [markdown]
# ### Центр

# %%
# визуализируем соотношение площади в центре и кол-ва квартир. 
total_area_visual_center = spb_city_center['total_area'].plot(kind='hist', bins=100, range=(0,100), title='Общая площадь в центре', grid=True)
total_area_visual_center.set_xlabel('Площадь квартиры')
total_area_visual_center.set_ylabel('Кол-во квартир')
spb_city_center['total_area'].describe()
# Out:
# count    3742.000000
# mean       83.954706
# std        41.072811
# min        19.000000
# 25%        54.025000
# 50%        75.000000
# 75%       102.160000
# max       249.700000
# Name: total_area, dtype: float64

# %% [markdown]
# Мы уже анализировали квартиры в центре и ожидаемо, что ближе к центру, тем больше квартиры.

# %%
# визуализируем соотношение последнего прайса в центре и кол-ва квартир
last_price_visual_center = spb_city_center['last_price'].plot(kind='hist', bins=70, range=(1000000,14000000), title='Распределение кол-ва квартир по цене в центре', grid=True)
last_price_visual_center.set_xlabel('Суммы продажи')
last_price_visual_center.set_ylabel('Кол-во квартир')
spb_city_center['last_price'].describe()
# Out:
# count    3.742000e+03
# mean     1.234285e+07
# std      1.388130e+07
# min      1.600000e+06
# 25%      6.350000e+06
# 50%      8.707500e+06
# 75%      1.320000e+07
# max      3.300000e+08
# Name: last_price, dtype: float64

# %% [markdown]
# В сравнении с общей выборкой, прайс ожидаемо двигается вперед.

# %%
# визуализируем соотношение кол-ва комнат и кол-ва квартир в центре. 
rooms_visual_center = spb_city_center['rooms'].plot(kind='hist', bins=40, range=(0,16), title='Категоризация квартир по кол-ву комнат в центре', grid=True)
rooms_visual_center.set_xlabel('Кол-во комнат в кв.')
rooms_visual_center.set_ylabel('Кол-во квартир')
spb_city_center['rooms'].describe()
# Out:
# count    3742.000000
# mean        2.664618
# std         1.230254
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max         7.000000
# Name: rooms, dtype: float64

# %% [markdown]
# Наиболее популярные квартиры в ценральной части 3х комнатные в отличие от общей выборки, где 1 и 2 квартиры самые востребованные.

# %%
# визуализируем соотношение высоты потолков и кол-ва квартир. 
ceiling_height_visual_center = spb_city_center['ceiling_height'].plot(kind='hist', bins=70, range=(2.5,3.2), title='Категоризация кв. по высоте потолков в центре', grid=True)
ceiling_height_visual_center.set_xlabel('Высота потолка')
ceiling_height_visual_center.set_ylabel('Кол-во квартир')
spb_city_center['ceiling_height'].describe()
# Out:
# count    3742.000000
# mean        2.905687
# std         0.334874
# min         2.500000
# 25%         2.650000
# 50%         2.775000
# 75%         3.100000
# max         4.900000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Преобладание высоты в пределах 2,7 м. ожидаемо т.к мы заполняли пропуски медианными значениеями, отдельно хочу отметить выбивающиеся значения 3,0 и 3,2 м., думаю это обусловенно большими квартирами в центре.

# %%
# просматриваем зависимость между кол-вом комнат и ценой в центральной части.  
compare_rooms_center = spb_city_center.pivot_table(index = 'rooms', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
compare_rooms_center.columns = ['mean', 'count', 'median']
compare_rooms_center.query('count > 50').plot(y = 'median')

compare_rooms_center.query('count > 50').sort_values('median', ascending = False)

spb_city_center['rooms'].corr(spb_city_center['last_price'])
# Out:
# 0.3194676460231619

# %% [markdown]
# Корреляция весьма низкия, согласно графику можно заметить, что чем больше комнат, тем ниже стоимость за квадратный метр. Я промониторил рынок недвижимости в Петербурге на сайтах.В сравнении с общими данными есть разница, обусловленная она считаю тем, что в центре очень большое кол-во аппартаментов с высокой стоимостью.

# %%
# просматриваем зависимость между этажом и ценой за квадратный метр.
compare_categ_floor_center = spb_city_center.pivot_table(index = 'categ_floor', values = 'cost_for_metre', aggfunc = ['mean', 'count', 'median'])
compare_categ_floor_center.columns = ['mean', 'count', 'median']
compare_categ_floor_center.plot(y = 'median')
compare_categ_floor_center
# Out:
#                       mean  count     median
# categ_floor
# другой       143838.749264   2718  126807.77
# первый       120966.530367    409  106837.61
# последний    131497.723350    615  115117.89

# %% [markdown]
# Относительно обших выводов сравним только "первый" и последний этажи, разница в стоимости в 13%, тогда как на общие.

# %%
# просматриваем зависимость удаленности кв. от центра и ценой за кв. метр. 
spb_city_center.plot(kind = 'scatter', y = 'last_price', x = 'cityCenters_nearest', alpha = 0.3)

spb_city_center['cityCenters_nearest'].corr(spb_city_center['last_price'])
# Out:
# -0.12358703691408715

# %% [markdown]
# Четкой зависимости в пределах центра нет.

# %%
# изучаем зависимость цены в центре от дня выставления обьявления. 
compare_week_exposition_center = spb_city_center.pivot_table(index = 'week_exposition', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
compare_week_exposition_center.columns = ['mean', 'count', 'median']
compare_week_exposition_center.plot(y = 'median')

compare_week_exposition_center.sort_values('median', ascending = False)
# Out:
#                          mean  count   median
# week_exposition
# 0                1.250645e+07    563  9000000
# 6                1.296933e+07    219  8970000
# 2                1.221548e+07    641  8812000
# 3                1.283395e+07    762  8625000
# 1                1.227146e+07    630  8592628
# 4                1.172607e+07    644  8500000
# 5                1.206126e+07    283  8250000

# %%
# изучаем зависимость цены в центре от месяца выставления обьявления. 
compare_month_exposition_center = spb_city_center.pivot_table(index = 'month_exposition', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
compare_month_exposition_center.columns = ['mean', 'count', 'median']
compare_month_exposition_center.plot(y = 'median')

compare_month_exposition_center.sort_values('median', ascending = False)
# Out:
#                           mean  count   median
# month_exposition
# 3                 1.219669e+07    395  9150000
# 2                 1.294626e+07    404  9004500
# 9                 1.194328e+07    328  8995000
# 7                 1.235077e+07    295  8990000
# 11                1.234137e+07    370  8960000
# 1                 1.271757e+07    232  8875000
# 8                 1.313869e+07    288  8725000
# 5                 1.180651e+07    221  8603000
# 6                 1.234654e+07    300  8525000
# 4                 1.278969e+07    358  8500000
# 10                1.121940e+07    309  8300000
# 12                1.206060e+07    242  7700000

# %%
# изучаем зависимость цены в центре от года выставления обьявления. 
compare_year_exposition_center = spb_city_center.pivot_table(index = 'year_exposition', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
compare_year_exposition_center.columns = ['mean', 'count', 'median']
compare_year_exposition_center.plot(y = 'median')

compare_year_exposition_center.sort_values('median', ascending = False)
# Out:
#                          mean  count    median
# year_exposition
# 2014             1.764420e+07     16  12649560
# 2015             1.664807e+07    202   9816985
# 2019             1.344006e+07    431   8995000
# 2016             1.235850e+07    480   8950131
# 2017             1.222126e+07   1404   8700000
# 2018             1.129722e+07   1209   8500000

# %% [markdown]
# 1. Зависимость от дней.
# - Есть различия от общей выборки. Если в общей выборке пик у нас во вторник и к выходным наблюдаем снижение цены, то в центре наоборот всплеск деловой активности идет к выходным.
#
# 2. Зависимость от месяца.
# - Отмечу, что более стабильный спрос в отличие от общей выборки.
#
# 3. Зависимость от года.
# - Так же, как и в общей выборке, можем с ростом сервиса увеличивается и кол-во объявлений.

# %%
# сортируем кол-во квартир по кол-ву дней продажи в центре
days_exposition_visual_center = spb_city_center['days_exposition'].plot(kind='hist', bins=55, range=(40,100), title='Категоризация от момента размещения обьявления до продажи квартиры в центре', grid=True)
days_exposition_visual_center.set_xlabel('Дни размещения')
days_exposition_visual_center.set_ylabel('Кол-во квартир')
spb_city_center['days_exposition'].describe()
# Out:
# count    3104.000000
# mean      184.781894
# std       176.560696
# min         3.000000
# 25%        54.000000
# 50%       118.000000
# 75%       272.000000
# max       729.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Относительно общей выборки сроки продажи увеличиваются, думаю это связано, что цена в центральной части значительно выше.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# После проведенного анализа выявлено следующее:
#
# 1) Близость к центру обеспечивает высокую стоимость жилья за исключением некоторых районов типа Петергофа, которые находятся за пределами центра, однако имеют высокую стоимость;
#
# 2) В общей выборке по Лен. области в среднем наиболее популярны квартиры площадью: 40 - 45м2, тогда, как в центре наиболее популярны квартиры ближе к 100м2., в данном случае необходимо учитывать, что в центре много исторических построек с большим метражом. Так же стоит отметить, что в общей выборке наиболее популярны квартиры 1-2 комнатные, тогда, как в центре 3х;
#
# 3) В общем по Лен. области преобладают стандартные квартиры с высотой потолков 2,5-2,7 м., как мы помним согласно документу - СНиП 31-01-2003 Петербург не относится к климатическим районам IА, IБ, IГ, IД и IVA и минимальная высота потолка 2.5м. Однако ближе к центру потолки тянутся ближе к 3м., тут можем так же предположить ввиду исторических особеностей;
#
# 4) Квартиры в центральном районе продаются дольше, чем в общем по выборке, тут скорее всего дело в том, что в центре квартиры дороже;
#
# 5) Несмотря на то, что ценник на последнем и первом этаже ниже, люди стремятся купить квартиры на других этажах, здесь действует скорее принцип того, что такие квартиры менее проблемные (например протек крыши на последнем этаже);
#
# 6) Можно выделить падение спроса после начала
#
# Подводя итог вышесказанного отметим, что наиболее оказывающим влияние на цену квартиры имеет местоположение относильно центральной части (Санкт-Петербург) с небольшими отклонениями. (районы вроде Петергофа). Усиливающими факторами являются: кол-во комнат, этажность, высота потолка, которые наиболее коррелируют приближаясь к центру.
